# %%
import numpy as np

# %%
# attribute of numpy
arr= np.array(((1,2),(3,"ABC")))# value,datatype
print(arr)

print(arr.ndim)
print(arr.shape)
print(type(arr))
print(arr.dtype)
# Out:
# [[1 2]
#  [3 4]]
# 2
# (2, 2)
# <class 'numpy.ndarray'>
# int64
